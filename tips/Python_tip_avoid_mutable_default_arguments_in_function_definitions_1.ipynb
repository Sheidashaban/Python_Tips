# %% [markdown]
# # Python Tip: Avoid mutable default arguments in function definitions
#
# Using mutable objects like lists or dictionaries as default arguments in function definitions can lead to unexpected behavior and bugs. Instead, set default arguments to None and initialize them within the function if needed.
#
# **Generated on:** 2025-12-12

# %%
```pythondef process_data(data=None):    if data is None:        data = []  # Initialize data as an empty list if not provided    data.append(100)    return dataresult1 = process_data()result2 = process_data()print(result1)  # Output: [100]print(result2)  # Output: [100]```COMMENTS:- By setting the default argument `data=None`, we ensure that a new list is created for each function call.- This prevents unexpected behavior due to shared mutable default arguments.
