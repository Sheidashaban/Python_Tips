# %% [markdown]
# # Python Tip: Avoid mutable default arguments in functions
#
# Using mutable objects (like lists, dictionaries) as default arguments can lead to unexpected behavior. Instead, use None and initialize the mutable object inside the function.
#
# **Generated on:** 2025-12-17

# %%
```pythondef process_data(data=None):    if data is None:        data = []  # Initialize an empty list if data is not provided    data.append('new_item')    return dataresult = process_data()print(result)  # Output: ['new_item']result2 = process_data(['existing_item'])print(result2)  # Output: ['existing_item', 'new_item']```COMMENTS:- In this example, we define a function `process_data` with a default argument `data=None`.- Inside the function, we check if `data` is None, and if so, we initialize it as an empty list. This ensures that each call to the function works with a fresh copy of the list.
