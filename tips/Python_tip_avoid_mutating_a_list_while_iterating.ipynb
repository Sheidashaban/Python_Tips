# %% [markdown]
# # Python Tip: Avoid Mutating a List While Iterating
#
# Modifying a list while iterating over it can lead to unexpected behavior or errors. To avoid this, create a copy of the list before iterating to safely make changes.
#
# **Generated on:** 2025-11-04

# %%
```pythonoriginal_list = [1, 2, 3, 4, 5]# Create a copy of the original listcopy_list = original_list.copy()# Modify the original listfor num in original_list:    if num % 2 == 0:        original_list.remove(num)print(copy_list)  # Copy remains unchangedprint(original_list)  # Original list modified safely```COMMENTS:- We create a copy of the original list using the `copy()` method to avoid modifying the list we are iterating over.- Within the loop, we remove even numbers from the `original_list` without causing any issues due to iterating over it.
