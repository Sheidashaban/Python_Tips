# %% [markdown]
# # Python Tip: Avoid Repeated Iterations with the any() Function
#
# Use the any() function to efficiently check if any element in an iterable satisfies a condition, avoiding the need for manual iterations.
#
# **Generated on:** 2025-11-03

# %%
```python# Check if any number in a list is greater than 10numbers = [5, 8, 12, 3]if any(num > 10 for num in numbers):    print("At least one number is greater than 10")```COMMENTS:- The any() function returns True if at least one element in the iterable satisfies the specified condition.- In this example, we use a generator expression inside any() to check if any number in the 'numbers' list is greater than 10.
