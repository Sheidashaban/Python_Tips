# %% [markdown]
# # Python Tip: Safely Handle File Operations with "with" Statement
#
# Use the "with" statement to automatically close files and ensure proper resource cleanup.
#
# **Generated on:** 2025-11-17

# %%
```python# Open and read a file using "with" statementwith open('example.txt', 'r') as file:    data = file.read()    print(data)# File is automatically closed after exiting the "with" block```COMMENTS:- The "with" statement automatically closes the file once we exit the block, ensuring proper resource management.- This helps avoid common errors like forgetting to close the file after reading or writing data.
