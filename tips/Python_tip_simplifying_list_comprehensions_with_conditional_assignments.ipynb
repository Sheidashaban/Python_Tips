# %% [markdown]
# # Python Tip: Simplifying List Comprehensions with Conditional Assignments
#
# Use conditional assignments within list comprehensions to make your code more concise and readable.
#
# **Generated on:** 2025-11-12

# %%
```python# List comprehension with conditional assignmentnumbers = [1, 2, 3, 4, 5]squared = [num**2 if num % 2 == 0 else num for num in numbers]print(squared)  # Output: [1, 4, 3, 16, 5]```COMMENTS:- In the example, the list comprehension squares the number if it's even (num % 2 == 0) and keeps it as is if it's odd.- This technique eliminates the need for a separate if-else statement, making the code more compact and expressive.
