# %% [markdown]
# # Python Tip: Use dictionary get() method with a default value
#
# Avoid KeyError by using get() method with a default value.
#
# **Generated on:** 2025-11-25

# %%
```pythonstudent_scores = {'Alice': 85, 'Bob': 90, 'Charlie': 88}# Accessing score for 'David' with default value of 0 if key not foundscore = student_scores.get('David', 0)print(score)  # Output: 0```COMMENTS:This tip helps prevent KeyError if the key is not found in the dictionary by providing a default value to return. In this example, if 'David' is not in the dictionary, the default value of 0 is returned instead.
