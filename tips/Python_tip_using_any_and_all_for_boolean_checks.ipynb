# %% [markdown]
# # Python Tip: Using any and all for boolean checks
#
# The any() function returns True if any element is True, while all() returns True only if all elements are True. Great for checking conditions across sequences.
#
# **Generated on:** 2026-06-20

# %%
numbers = [1, 2, 3, 4, 5]# Check if any number is greater than 4has_large = any(num > 4 for num in numbers)print(has_large)  # True# Check if all numbers are positiveall_positive = all(num > 0 for num in numbers)print(all_positive)  # True# Check if any string is emptystrings = ['hello', 'world', '', 'python']has_empty = any(not s for s in strings)print(has_empty)  # True
