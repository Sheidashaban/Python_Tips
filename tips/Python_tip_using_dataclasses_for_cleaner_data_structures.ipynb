# %% [markdown]
# # Python Tip: Using dataclasses for cleaner data structures
#
# Dataclasses (Python 3.7+) reduce boilerplate code when creating classes that primarily store data, automatically generating __init__, __repr__, and other methods.
#
# **Generated on:** 2026-06-10

# %%
from dataclasses import dataclass# Without dataclass - lots of boilerplateclass PersonOld:    def __init__(self, name, age, city):        self.name = name        self.age = age        self.city = city        def __repr__(self):        return f"Person(name={self.name}, age={self.age}, city={self.city})"# With dataclass - much cleaner!@dataclassclass Person:    name: str    age: int    city: strperson = Person("Alice", 30, "Paris")print(person)  # Person(name='Alice', age=30, city='Paris')
