# %% [markdown]
# # Python Tip: Using defaultdict for Default Dictionary Values
#
# defaultdict from the collections module allows setting default values for dictionary keys, avoiding KeyErrors.
#
# **Generated on:** 2025-12-21

# %%
```pythonfrom collections import defaultdict# Initialize defaultdict with default value 0 for missing keysword_freq = defaultdict(int)# Update word frequency count without checking if key existswords = ['apple', 'banana', 'apple']for word in words:    word_freq[word] += 1print(word_freq)```COMMENTS:- defaultdict(int) creates a dictionary where missing keys default to 0.- Incrementing word frequency counts directly without explicit key checking.
