# %% [markdown]
# # Python Tip: Using Enumerate for Index-Value Iteration
#
# Enumerate simplifies looping over an iterable while tracking the index.
#
# **Generated on:** 2025-12-16

# %%
```pythonfruits = ['apple', 'banana', 'cherry']for index, fruit in enumerate(fruits):    print(f"At index {index}: {fruit}")```COMMENTS:- `enumerate()` returns both the index and value of each element in the list.- This is especially useful when you need to know the index while iterating over the elements.
