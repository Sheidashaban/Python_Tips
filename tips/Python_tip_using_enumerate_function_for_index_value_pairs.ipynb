# %% [markdown]
# # Python Tip: Using Enumerate Function for Index-Value Pairs
#
# Enumerate function simplifies iterating with index-value pairs.
#
# **Generated on:** 2025-11-28

# %%
```pythonmy_list = ['apple', 'banana', 'cherry']for index, value in enumerate(my_list):    print(f'Index: {index}, Value: {value}')```COMMENTS:- The `enumerate()` function returns both the index and value of elements in an iterable.- This code snippet demonstrates how to iterate over a list while accessing both the index and the value at the same time.
