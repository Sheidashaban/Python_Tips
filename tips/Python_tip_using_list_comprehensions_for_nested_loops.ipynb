# %% [markdown]
# # Python Tip: Using List Comprehensions for Nested Loops
#
# Use list comprehensions to create concise code for nested loops.
#
# **Generated on:** 2025-11-10

# %%
```python# Create a 2D list using nested loopsmatrix = [[i*j for j in range(1, 4)] for i in range(1, 4)]print(matrix)  # Output: [[1, 2, 3], [2, 4, 6], [3, 6, 9]]```COMMENTS:- In this example, a 3x3 matrix is created using nested loops inside a list comprehension.- The expression `i*j` generates each element of the matrix, where `i` and `j` iterate over the specified ranges.
