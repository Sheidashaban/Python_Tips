# %% [markdown]
# # Python Tip: Using List Comprehensions for Nested Loops
#
# List comprehensions can be used to create nested loops concisely and elegantly in Python, reducing code complexity and improving readability.
#
# **Generated on:** 2025-11-26

# %%
```python# Create a 2D list using nested loopsrows = 3cols = 3matrix = [[i * cols + j for j in range(cols)] for i in range(rows)]print(matrix)```# Create a 2D list using a list comprehension with nested loops. The outer loop iterates over rows, and the inner loop iterates over columns to populate the matrix.
