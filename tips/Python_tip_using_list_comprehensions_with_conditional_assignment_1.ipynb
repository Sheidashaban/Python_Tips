# %% [markdown]
# # Python Tip: Using List Comprehensions with Conditional Assignment
#
# Simplify conditional assignment in list comprehensions.
#
# **Generated on:** 2025-12-26

# %%
```python# Assign 'even' if number is even, else 'odd' for each element in the listnumbers = [1, 2, 3, 4, 5]result = ['even' if num % 2 == 0 else 'odd' for num in numbers]print(result)  # Output: ['odd', 'even', 'odd', 'even', 'odd']```COMMENTS:- The list comprehension checks if each number in `numbers` is even using the conditional `if num % 2 == 0`.- Based on the condition, it assigns 'even' if true, else 'odd' for each number in the list.
