# %% [markdown]
# # Python Tip: Using Python's defaultdict for Default Values
#
# defaultdict from the collections module can be used to provide default values for keys that are not present in a dictionary, avoiding KeyErrors. It simplifies handling missing keys in a dictionary.
#
# **Generated on:** 2025-11-21

# %%
```pythonfrom collections import defaultdict# Initialize defaultdict with int type for default value 0counts = defaultdict(int)# Increment count for each element, even if it doesn't existelements = ['a', 'b', 'a', 'c', 'b']for element in elements:    counts[element] += 1print(counts)  # Output: defaultdict(<class 'int'>, {'a': 2, 'b': 2, 'c': 1})```# In this example, we use defaultdict to count the occurrences of elements in a list. If the element doesn't exist in the dictionary, defaultdict automatically initializes its count to the default value of 0, preventing KeyErrors.
