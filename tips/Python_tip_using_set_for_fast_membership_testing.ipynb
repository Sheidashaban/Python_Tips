# %% [markdown]
# # Python Tip: Using set for fast membership testing
#
# Sets provide O(1) lookup time compared to lists with O(n). Use sets when you need to check if an item exists in a collection frequently.
#
# **Generated on:** 2026-06-10

# %%
# Slow with list (O(n) lookup)allowed_users_list = ['alice', 'bob', 'charlie', 'david'] * 1000is_allowed = 'bob' in allowed_users_list  # Slow for large lists# Fast with set (O(1) lookup)allowed_users_set = {'alice', 'bob', 'charlie', 'david'}is_allowed = 'bob' in allowed_users_set  # Much faster!# Remove duplicates from a listnumbers = [1, 2, 2, 3, 3, 3, 4, 5, 5]unique_numbers = list(set(numbers))print(unique_numbers)  # [1, 2, 3, 4, 5]
