# %% [markdown]
# # Python Tip: Using string join instead of concatenation
#
# Using join() is much more efficient than concatenating strings with + in a loop, especially for large numbers of strings.
#
# **Generated on:** 2026-06-30

# %%
words = ['Python', 'is', 'awesome', 'and', 'powerful']# Slow - string concatenation in loopresult = ''for word in words:    result += word + ' '  # Creates new string each timeresult = result.strip()# Fast - using joinresult = ' '.join(words)  # Much more efficientprint(result)  # Python is awesome and powerful# Join with different separatorscsv = ','.join(['Alice', '30', 'Paris'])print(csv)  # Alice,30,Parispath = '/'.join(['home', 'user', 'documents', 'file.txt'])print(path)  # home/user/documents/file.txt
