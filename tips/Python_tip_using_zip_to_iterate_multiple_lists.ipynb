# %% [markdown]
# # Python Tip: Using zip to iterate multiple lists
#
# The zip() function combines multiple iterables element-by-element, making it easy to iterate over them in parallel.
#
# **Generated on:** 2026-02-07

# %%
names = ['Alice', 'Bob', 'Charlie']ages = [25, 30, 35]cities = ['Paris', 'London', 'Berlin']# Iterate over multiple lists at oncefor name, age, city in zip(names, ages, cities):    print(f"{name} is {age} years old and lives in {city}")# Create a dictionary from two listsuser_dict = dict(zip(names, ages))print(user_dict)  # {'Alice': 25, 'Bob': 30, 'Charlie': 35}
