# %% [markdown]
# # Python Tip: Utilize namedtuple for Immutable Data Structures
#
# namedtuple from collections module creates lightweight, immutable data structures ideal for holding records or objects with a fixed set of fields.
#
# **Generated on:** 2025-11-23

# %%
```pythonfrom collections import namedtuple# Define a namedtuple for a Point with x and y coordinatesPoint = namedtuple('Point', ['x', 'y'])# Create a Point objectp1 = Point(1, 2)# Access fields using attribute namesprint(p1.x, p1.y)```COMMENTS:- By using namedtuple, you get the benefits of an immutable object with attribute access.- This is useful for scenarios where you need a simple data structure without defining a full class.
